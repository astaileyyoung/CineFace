# %%
import ast
import json
import shutil
from pathlib import Path 
from functools import partial

import numpy as np
import pandas as pd
from tqdm.auto import tqdm

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('./data/faces.csv', index_col=0)
df.head()
# Out:
#    imdb_id  frame_num  face_num    x1   y1    x2   y2  img_height  img_width  \
# 0  1811020        192         0   798  196   916  314        1080       1920
# 1  1811020        216         0  1068  389  1491  812        1080       1920
# 2  1811020        216         1   912   17  1205  311        1080       1920
# 3  1811020        240         0  1090  106  1384  400        1080       1920
# 4  1811020        240         1   674  522   968  816        1080       1920
#
#      area  pct_of_frame  season  episode  \
# 0   13924         0.007       1        1
# 1  178929         0.086       1        1
# 2   86142         0.042       1        1
# 3   86436         0.042       1        1
# 4   86436         0.042       1        1
#
#                                             encoding filename character  \
# 0  [-0.1581144630908966, 0.11875572055578232, 0.0...      NaN       NaN
# 1  [-0.035924218595027924, 0.09460100531578064, 0...      NaN       NaN
# 2  [-0.10312943160533905, 0.1261938065290451, 0.0...      NaN       NaN
# 3  [-0.18763160705566406, 0.08110883831977844, 0....      NaN       NaN
# 4  [-0.11751651763916016, 0.1057925745844841, 0.0...      NaN       NaN
#
#    cast_id
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
class_df = df[df['character'].notna()]
class_df.head()
# Out:
#     imdb_id  frame_num  face_num   x1   y1    x2   y2  img_height  img_width  \
# 7   1811020        384         0  497  208   849  560        1080       1920
# 8   1811020        408         0  390  208   742  560        1080       1920
# 9   1811020        432         0  198   99   807  707        1080       1920
# 10  1811020        456         0  445  160  1053  769        1080       1920
# 11  1811020        480         0  260  160   868  769        1080       1920
#
#       area  pct_of_frame  season  episode  \
# 7   123904         0.060       1        1
# 8   123904         0.060       1        1
# 9   370272         0.179       1        1
# 10  370272         0.179       1        1
# 11  370272         0.179       1        1
#
#                                              encoding          filename  \
# 7   [-0.09047424793243408, 0.08664017170667648, 0....  S01E01_384_0.png
# 8   [-0.15323874354362488, 0.10863395780324936, 0....  S01E01_408_0.png
# 9   [-0.1460844725370407, 0.09071134030818939, 0.0...  S01E01_432_0.png
# 10  [-0.11816225200891495, 0.12249065190553665, 0....  S01E01_456_0.png
# 11  [-0.09060899913311005, 0.09976912289857864, 0....  S01E01_480_0.png
#
#           character  cast_id
# 7   Carrie Mathison    132.0
# 8   Carrie Mathison    132.0
# 9   Carrie Mathison    132.0
# 10  Carrie Mathison    132.0
# 11  Carrie Mathison    132.0

# %%
classes = {x: num for num, x in enumerate(list(set(class_df['character'])))}
classes
# Out:
# {'Nicholas Brody': 0,
#  'Numan': 1,
#  'Etai Luskin': 2,
#  'Sandy Langmore': 3,
#  'Jonas': 4,
#  'Clint Prower': 5,
#  'Jim Lippard': 6,
#  'Jalal Haqqani': 7,
#  'Lynne Reed': 8,
#  'Dar Adal': 9,
#  'Jessica Brody': 10,
#  'Ray Conlin': 11,
#  'Otto During': 12,
#  'Reda Hashem': 13,
#  "Abdul Qadir G'ulom": 14,
#  'Paksima': 15,
#  'Aayan Ibrahim': 16,
#  'Haissam Haqqani': 17,
#  'Ellen Mathison': 18,
#  'Max Piotrowski': 19,
#  'Senator Sam Paley': 20,
#  'Dante Allen': 21,
#  'Peter Quinn': 22,
#  'John Zabel': 23,
#  'Ivan Krupin': 24,
#  'Dana Brody': 25,
#  'Simone Martin': 26,
#  'President Ben Hayes': 27,
#  'Saul Berenson': 28,
#  'Carrie Mathison': 29,
#  'Thomas Anson': 30,
#  'John Redmond': 31,
#  'Franny': 32,
#  'Christine Lonas': 33,
#  'David Wellington': 34,
#  'Chris Brody': 35,
#  "Brett O'Keefe": 36,
#  'Mike Dunn': 37,
#  'Tom Walker': 38,
#  'Fara Sherazi': 39,
#  'Frank Mathison': 40,
#  'Issa Nazir': 41,
#  'Martha Boyd': 42,
#  'President Elizabeth Keane': 43,
#  'Maggie Mathison': 44,
#  'Sekou Bah': 45,
#  'Majid Javadi': 46,
#  'Helen Walker': 47,
#  'Allison Carr': 48,
#  'Jenna Bragg': 49,
#  'Tasneem Qureishi': 50,
#  'Vice President William Walden': 51,
#  'David Estes': 52,
#  'Tova Rivlin': 53,
#  'Rob Emmons': 54,
#  'Yevgeny Gromov': 55,
#  'Mike Faber': 56,
#  'Dennis Boyd': 57,
#  'Agent Maslin': 58,
#  'Mira Berenson': 59,
#  'Aasar Khan': 60,
#  'Vice President Ralph Warner': 61,
#  'Viktor Makarov': 62,
#  'Virgil Piotrowski': 63,
#  'Bunny Latif': 64,
#  'Andrew Lockhart': 65,
#  'Astrid': 66,
#  'Laura Sutton': 67,
#  'Aileen Morgan': 68}

# %%
X = np.array([np.array(ast.literal_eval(x)) for x in class_df['encoding'].tolist()])
y = np.array([classes[x] for x in class_df['character']])
print(X.shape)
print(y.shape)
# Out:
# (126839, 128)
# (126839,)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.20)
print('x_train: ', x_train.shape)
print('x_test: ', x_test.shape)
print('y_train: ', y_train.shape)
print('y_test: ', y_test.shape)
# Out:
# x_train:  (101471, 128)
# x_test:  (25368, 128)
# y_train:  (101471,)
# y_test:  (25368,)

# %%
neigh = KNeighborsClassifier()
neigh.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
pred = neigh.predict(x_test)
pred
# Out:
# array([28, 25, 59, ..., 63, 29, 43])

# %%
correct = 0
for x in range(pred.shape[0]):
    if pred[x] == y_test[x]:
        correct += 1
print(correct, y_test.shape[0], (correct/y_test.shape[0]))
# Out:
# 25140 25368 0.9910122989593189

# %%
def process(row,
            classifier):
    if pd.isnull(row['character']):
        a = ast.literal_eval(row['encoding'])
        a = np.array(a)
        pred = classifier.predict(a.reshape(1, -1))
        return pred
    else:
        return np.nan

# %%
f = partial(process, classifier=neigh)

# %%
tqdm().pandas()
p = df.progress_apply(f, axis=1)
p
# Out:
# 0it [00:00, ?it/s]
#   0%|          | 0/249536 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[72], line 2
#       1 tqdm().pandas()
# ----> 2 p = df.progress_apply(f, axis=1)
#       3 p
#
# File ~/local/anaconda/envs/homeland/lib/python3.9/site-packages/tqdm/std.py:920, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     917 # Apply the provided function (in **kwargs)
#     918 # on the df using our wrapper (which provides bar updating)
#     919 try:
# --> 920     return getattr(df, df_function)(wrapper, **kwargs)
#     921 finally:
#     922     t.close()
#
# File ~/local/anaconda/envs/homeland/lib/python3.9/site-packages/pandas/core/frame.py:10037, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10025 from pandas.core.apply import frame_apply
#   10027 op = frame_apply(
#   10028     self,
#   10029     func=func,
#    (...)
#   10035     kwargs=kwargs,
#   10036 )
# > 10037 return op.apply().__finalize__(self, method="apply")
#
# File ~/local/anaconda/envs/homeland/lib/python3.9/site-packages/pandas/core/apply.py:831, in FrameApply.apply(self)
#     828 elif self.raw:
#     829     return self.apply_raw()
# --> 831 return self.apply_standard()
#
# File ~/local/anaconda/envs/homeland/lib/python3.9/site-packages/pandas/core/apply.py:957, in FrameApply.apply_standard(self)
#     956 def apply_standard(self):
# --> 957     results, res_index = self.apply_series_generator()
#     959     # wrap results
#     960     return self.wrap_results(results, res_index)
#
# File ~/local/anaconda/envs/homeland/lib/python3.9/site-packages/pandas/core/apply.py:973, in FrameApply.apply_series_generator(self)
#     970 with option_context("mode.chained_assignment", None):
#     971     for i, v in enumerate(series_gen):
#     972         # ignore SettingWithCopy here in case the user mutates
# --> 973         results[i] = self.func(v, *self.args, **self.kwargs)
#     974         if isinstance(results[i], ABCSeries):
#     975             # If we have a view on v, we need to make a copy because
#     976             #  series_generator will swap out the underlying data
#     977             results[i] = results[i].copy(deep=False)
#
# File ~/local/anaconda/envs/homeland/lib/python3.9/site-packages/tqdm/std.py:915, in tqdm.pandas.<locals>.inner_generator.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     909 def wrapper(*args, **kwargs):
#     910     # update tbar correctly
#     911     # it seems `pandas apply` calls `func` twice
#     912     # on the first column/row to decide whether it can
#     913     # take a fast or slow code path; so stop when t.total==t.n
#     914     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 915     return func(*args, **kwargs)
#
# Cell In[65], line 6, in process(row, classifier)
#       4     a = ast.literal_eval(row['encoding'])
#       5     a = np.array(a)
# ----> 6     pred = classifier.predict(a.reshape(1, -1))
#       7     return pred
#       8 else:
#
# File ~/local/anaconda/envs/homeland/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:254, in KNeighborsClassifier.predict(self, X)
#     250 if self.weights == "uniform":
#     251     if self._fit_method == "brute" and ArgKminClassMode.is_usable_for(
#     252         X, self._fit_X, self.metric
#     253     ):
# --> 254         probabilities = self.predict_proba(X)
#     255         if self.outputs_2d_:
#     256             return np.stack(
#     257                 [
#     258                     self.classes_[idx][np.argmax(probas, axis=1)]
#    (...)
#     261                 axis=1,
#     262             )
#
# File ~/local/anaconda/envs/homeland/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:355, in KNeighborsClassifier.predict_proba(self, X)
#     351         return probabilities
#     353     # In that case, we do not need the distances to perform
#     354     # the weighting so we do not compute them.
# --> 355     neigh_ind = self.kneighbors(X, return_distance=False)
#     356     neigh_dist = None
#     357 else:
#
# File ~/local/anaconda/envs/homeland/lib/python3.9/site-packages/sklearn/neighbors/_base.py:822, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     815 use_pairwise_distances_reductions = (
#     816     self._fit_method == "brute"
#     817     and ArgKmin.is_usable_for(
#     818         X if X is not None else self._fit_X, self._fit_X, self.effective_metric_
#     819     )
#     820 )
#     821 if use_pairwise_distances_reductions:
# --> 822     results = ArgKmin.compute(
#     823         X=X,
#     824         Y=self._fit_X,
#     825         k=n_neighbors,
#     826         metric=self.effective_metric_,
#     827         metric_kwargs=self.effective_metric_params_,
#     828         strategy="auto",
#     829         return_distance=return_distance,
#     830     )
#     832 elif (
#     833     self._fit_method == "brute" and self.metric == "precomputed" and issparse(X)
#     834 ):
#     835     results = _kneighbors_from_graph(
#     836         X, n_neighbors=n_neighbors, return_distance=return_distance
#     837     )
#
# File ~/local/anaconda/envs/homeland/lib/python3.9/site-packages/sklearn/metrics/_pairwise_distances_reduction/_dispatcher.py:259, in ArgKmin.compute(cls, X, Y, k, metric, chunk_size, metric_kwargs, strategy, return_distance)
#     178 """Compute the argkmin reduction.
#     179
#     180 Parameters
#    (...)
#     256 returns.
#     257 """
#     258 if X.dtype == Y.dtype == np.float64:
# --> 259     return ArgKmin64.compute(
#     260         X=X,
#     261         Y=Y,
#     262         k=k,
#     263         metric=metric,
#     264         chunk_size=chunk_size,
#     265         metric_kwargs=metric_kwargs,
#     266         strategy=strategy,
#     267         return_distance=return_distance,
#     268     )
#     270 if X.dtype == Y.dtype == np.float32:
#     271     return ArgKmin32.compute(
#     272         X=X,
#     273         Y=Y,
#    (...)
#     279         return_distance=return_distance,
#     280     )
#
# File sklearn/metrics/_pairwise_distances_reduction/_argkmin.pyx:90, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin64.compute()
#
# File ~/local/anaconda/envs/homeland/lib/python3.9/site-packages/threadpoolctl.py:440, in _ThreadpoolLimiter.__exit__(self, type, value, traceback)
#     437 def __enter__(self):
#     438     return self
# --> 440 def __exit__(self, type, value, traceback):
#     441     self.restore_original_limits()
#     443 @classmethod
#     444 def wrap(cls, controller, *, limits=None, user_api=None):
#
# KeyboardInterrupt:

# %%
X_pred = np.array([ast.literal_eval(x) for x in tqdm(df['encoding'], total=df.shape[0])])
# Out:
#   0%|          | 0/249536 [00:00<?, ?it/s]

# %%
y_pred = neigh.predict(X_pred)
y_pred
# Out:
# array([17,  9, 19, ..., 65, 45, 28])

# %%
num_to_class = {v: k for k, v in classes.items()}
df['pred'] = [num_to_class[x] for x in y_pred]
df.head()
# Out:
#    imdb_id  frame_num  face_num    x1   y1    x2   y2  img_height  img_width  \
# 0  1811020        192         0   798  196   916  314        1080       1920
# 1  1811020        216         0  1068  389  1491  812        1080       1920
# 2  1811020        216         1   912   17  1205  311        1080       1920
# 3  1811020        240         0  1090  106  1384  400        1080       1920
# 4  1811020        240         1   674  522   968  816        1080       1920
#
#      area  pct_of_frame  season  episode  \
# 0   13924         0.007       1        1
# 1  178929         0.086       1        1
# 2   86142         0.042       1        1
# 3   86436         0.042       1        1
# 4   86436         0.042       1        1
#
#                                             encoding filename character  \
# 0  [-0.1581144630908966, 0.11875572055578232, 0.0...      NaN       NaN
# 1  [-0.035924218595027924, 0.09460100531578064, 0...      NaN       NaN
# 2  [-0.10312943160533905, 0.1261938065290451, 0.0...      NaN       NaN
# 3  [-0.18763160705566406, 0.08110883831977844, 0....      NaN       NaN
# 4  [-0.11751651763916016, 0.1057925745844841, 0.0...      NaN       NaN
#
#    cast_id             pred
# 0      NaN  Haissam Haqqani
# 1      NaN         Dar Adal
# 2      NaN   Max Piotrowski
# 3      NaN    Aayan Ibrahim
# 4      NaN      Etai Luskin

# %%
df.to_csv(r'./data/predictions.csv')

# %%
def format_filepaths(row):
    e = str(row['episode'])
    s = str(row['season'])
    frame_num = str(row['frame_num'])
    face_num = str(row['face_num'])
    name = f'S{s.zfill(2)}E{e.zfill(2)}_{frame_num}_{face_num}.png'
    return name

# %%
names = df.apply(format_filepaths, axis=1)

# %%
temp = df.copy()
temp['fp'] = names
temp.head()
# Out:
#    imdb_id  frame_num  face_num    x1   y1    x2   y2  img_height  img_width  \
# 0  1811020        192         0   798  196   916  314        1080       1920
# 1  1811020        216         0  1068  389  1491  812        1080       1920
# 2  1811020        216         1   912   17  1205  311        1080       1920
# 3  1811020        240         0  1090  106  1384  400        1080       1920
# 4  1811020        240         1   674  522   968  816        1080       1920
#
#      area  pct_of_frame  season  episode  \
# 0   13924         0.007       1        1
# 1  178929         0.086       1        1
# 2   86142         0.042       1        1
# 3   86436         0.042       1        1
# 4   86436         0.042       1        1
#
#                                             encoding filename character  \
# 0  [-0.1581144630908966, 0.11875572055578232, 0.0...      NaN       NaN
# 1  [-0.035924218595027924, 0.09460100531578064, 0...      NaN       NaN
# 2  [-0.10312943160533905, 0.1261938065290451, 0.0...      NaN       NaN
# 3  [-0.18763160705566406, 0.08110883831977844, 0....      NaN       NaN
# 4  [-0.11751651763916016, 0.1057925745844841, 0.0...      NaN       NaN
#
#    cast_id             pred                fp
# 0      NaN  Haissam Haqqani  S01E01_192_0.png
# 1      NaN         Dar Adal  S01E01_216_0.png
# 2      NaN   Max Piotrowski  S01E01_216_1.png
# 3      NaN    Aayan Ibrahim  S01E01_240_0.png
# 4      NaN      Etai Luskin  S01E01_240_1.png

# %%
df['filename'] = names
df
# Out:
#         imdb_id  frame_num  face_num    x1   y1    x2   y2  img_height  \
# 0       1811020        192         0   798  196   916  314        1080
# 1       1811020        216         0  1068  389  1491  812        1080
# 2       1811020        216         1   912   17  1205  311        1080
# 3       1811020        240         0  1090  106  1384  400        1080
# 4       1811020        240         1   674  522   968  816        1080
# ...         ...        ...       ...   ...  ...   ...  ...         ...
# 249531  7126670      95544         1   880  280  1125  525        1080
# 249532  7126670      95544         2  1209  403  1503  697        1080
# 249533  7126670      95568         0   360  280   605  525        1080
# 249534  7126670      95568         1   880  280  1125  525        1080
# 249535  7126670      95568         2  1209  403  1503  697        1080
#
#         img_width    area  pct_of_frame  season  episode  \
# 0            1920   13924         0.007       1        1
# 1            1920  178929         0.086       1        1
# 2            1920   86142         0.042       1        1
# 3            1920   86436         0.042       1        1
# 4            1920   86436         0.042       1        1
# ...           ...     ...           ...     ...      ...
# 249531       1920   60025         0.029       8       12
# 249532       1920   86436         0.042       8       12
# 249533       1920   60025         0.029       8       12
# 249534       1920   60025         0.029       8       12
# 249535       1920   86436         0.042       8       12
#
#                                                  encoding            filename  \
# 0       [-0.1581144630908966, 0.11875572055578232, 0.0...    S01E01_192_0.png
# 1       [-0.035924218595027924, 0.09460100531578064, 0...    S01E01_216_0.png
# 2       [-0.10312943160533905, 0.1261938065290451, 0.0...    S01E01_216_1.png
# 3       [-0.18763160705566406, 0.08110883831977844, 0....    S01E01_240_0.png
# 4       [-0.11751651763916016, 0.1057925745844841, 0.0...    S01E01_240_1.png
# ...                                                   ...                 ...
# 249531  [-0.2143310308456421, 0.11155920475721359, 0.2...  S08E12_95544_1.png
# 249532  [-0.07177435606718063, 0.16331857442855835, 0....  S08E12_95544_2.png
# 249533  [-0.07891353964805603, 0.03790706396102905, 0....  S08E12_95568_0.png
# 249534  [-0.21665415167808533, 0.11300860345363617, 0....  S08E12_95568_1.png
# 249535  [-0.024056490510702133, 0.1442165970802307, 0....  S08E12_95568_2.png
#
#        character  cast_id             pred
# 0            NaN      NaN  Haissam Haqqani
# 1            NaN      NaN         Dar Adal
# 2            NaN      NaN   Max Piotrowski
# 3            NaN      NaN    Aayan Ibrahim
# 4            NaN      NaN      Etai Luskin
# ...          ...      ...              ...
# 249531       NaN      NaN        Sekou Bah
# 249532       NaN      NaN    Saul Berenson
# 249533       NaN      NaN  Andrew Lockhart
# 249534       NaN      NaN        Sekou Bah
# 249535       NaN      NaN    Saul Berenson
#
# [249536 rows x 18 columns]

# %%
temp_df = df[df['character'].isna()]
temp_df
# Out:
#         imdb_id  frame_num  face_num    x1   y1    x2   y2  img_height  \
# 0       1811020        192         0   798  196   916  314        1080
# 1       1811020        216         0  1068  389  1491  812        1080
# 2       1811020        216         1   912   17  1205  311        1080
# 3       1811020        240         0  1090  106  1384  400        1080
# 4       1811020        240         1   674  522   968  816        1080
# ...         ...        ...       ...   ...  ...   ...  ...         ...
# 249531  7126670      95544         1   880  280  1125  525        1080
# 249532  7126670      95544         2  1209  403  1503  697        1080
# 249533  7126670      95568         0   360  280   605  525        1080
# 249534  7126670      95568         1   880  280  1125  525        1080
# 249535  7126670      95568         2  1209  403  1503  697        1080
#
#         img_width    area  pct_of_frame  season  episode  \
# 0            1920   13924         0.007       1        1
# 1            1920  178929         0.086       1        1
# 2            1920   86142         0.042       1        1
# 3            1920   86436         0.042       1        1
# 4            1920   86436         0.042       1        1
# ...           ...     ...           ...     ...      ...
# 249531       1920   60025         0.029       8       12
# 249532       1920   86436         0.042       8       12
# 249533       1920   60025         0.029       8       12
# 249534       1920   60025         0.029       8       12
# 249535       1920   86436         0.042       8       12
#
#                                                  encoding            filename  \
# 0       [-0.1581144630908966, 0.11875572055578232, 0.0...    S01E01_192_0.png
# 1       [-0.035924218595027924, 0.09460100531578064, 0...    S01E01_216_0.png
# 2       [-0.10312943160533905, 0.1261938065290451, 0.0...    S01E01_216_1.png
# 3       [-0.18763160705566406, 0.08110883831977844, 0....    S01E01_240_0.png
# 4       [-0.11751651763916016, 0.1057925745844841, 0.0...    S01E01_240_1.png
# ...                                                   ...                 ...
# 249531  [-0.2143310308456421, 0.11155920475721359, 0.2...  S08E12_95544_1.png
# 249532  [-0.07177435606718063, 0.16331857442855835, 0....  S08E12_95544_2.png
# 249533  [-0.07891353964805603, 0.03790706396102905, 0....  S08E12_95568_0.png
# 249534  [-0.21665415167808533, 0.11300860345363617, 0....  S08E12_95568_1.png
# 249535  [-0.024056490510702133, 0.1442165970802307, 0....  S08E12_95568_2.png
#
#        character  cast_id             pred
# 0            NaN      NaN  Haissam Haqqani
# 1            NaN      NaN         Dar Adal
# 2            NaN      NaN   Max Piotrowski
# 3            NaN      NaN    Aayan Ibrahim
# 4            NaN      NaN      Etai Luskin
# ...          ...      ...              ...
# 249531       NaN      NaN        Sekou Bah
# 249532       NaN      NaN    Saul Berenson
# 249533       NaN      NaN  Andrew Lockhart
# 249534       NaN      NaN        Sekou Bah
# 249535       NaN      NaN    Saul Berenson
#
# [122697 rows x 18 columns]

# %%
def save_images(row,
                dst):
    dst_dir = dst.joinpath(row['pred'].replace(' ', '_'))
    if not dst_dir.exists():
        Path.mkdir(dst_dir, parents=True)
    fp = dst_dir.joinpath(row['filename']).absolute()
    src = Path('./data/images/').joinpath(row['filename']).absolute()
    shutil.copy(str(src), str(fp))

# %%
dst = Path('./data/predictions')
f = partial(save_images, dst=dst)
tqdm().pandas()
df.progress_apply(f, axis=1)
# Out:
# 0it [00:00, ?it/s]
#   0%|          | 0/249536 [00:00<?, ?it/s]
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#           ...
# 249531    None
# 249532    None
# 249533    None
# 249534    None
# 249535    None
# Length: 249536, dtype: object
