# %%
import cv2
import IPython
import numpy as np
import pandas as pd

# %%
def distance_from_center(row):
    x = int((row['x2'] - row['x1'])/2) + row['x1']
    y = int((row['y2'] - row['y1'])/2) + row['y1']
    
    xx = int(row['img_width']/2)
    yy = int(row['img_height']/2)
    a = abs(yy - y) 
    b = abs(xx - x)
    c = np.sqrt(a^2 + b^2)
    return round(c, 2)

# %%
def show_image(image):
    _, ret = cv2.imencode('.jpg', image)
    i = IPython.display.Image(data=ret)
    IPython.display.display(i)

# %%
def draw_to_center(row):
    cap = cv2.VideoCapture(row['filepath'])
    cap.set(cv2.CAP_PROP_POS_FRAMES, row['frame_num'])
    ret, frame = cap.read()
    x = int((row['x2'] - row['x1'])/2) + row['x1']
    y = int((row['y2'] - row['y1'])/2) + row['y1']
    
    xx = int(row['img_width']/2)
    yy = int(row['img_height']/2)

    cv2.circle(frame, (x,y), 5, (0, 0, 255), -1)
    cv2.circle(frame, (xx,yy), 5, (0, 0, 255), -1)
    cv2.line(frame, (x,y), (xx,yy), (0, 0, 255), 2)
    show_image(frame)

# %%
df = pd.read_csv('/home/amos/datasets/shining_bat.csv', index_col=0)
df.head()
# Out:
#     x1   y1   x2   y2  right_eye_x  right_eye_y  left_eye_x  left_eye_y  \
# 0  479   94  695  397          535          208         634         196
# 1  515  114  730  422          570          231         669         223
# 2  509  108  721  410          562          226         662         216
# 3  515   99  732  407          584          220         685         212
# 4  492  117  709  416          550          233         651         220
#
#    nose_x  nose_y  ...  mouth_left_y  confidence  frame_num  face_num  \
# 0     589     237  ...           311       0.999         24         0
# 1     623     276  ...           342       0.999         48         0
# 2     616     264  ...           329       0.999         72         0
# 3     648     261  ...           326       0.999         96         0
# 4     610     268  ...           333       1.000        120         0
#
#    img_width  img_height         filename  \
# 0       1280         720  shining_bat.mp4
# 1       1280         720  shining_bat.mp4
# 2       1280         720  shining_bat.mp4
# 3       1280         720  shining_bat.mp4
# 4       1280         720  shining_bat.mp4
#
#                                             filepath  distance_from_center  \
# 0  /home/amos/programs/CineFace/data/test_videos/...                 26.63
# 1  /home/amos/programs/CineFace/data/test_videos/...                 27.04
# 2  /home/amos/programs/CineFace/data/test_videos/...                 26.74
# 3  /home/amos/programs/CineFace/data/test_videos/...                 27.02
# 4  /home/amos/programs/CineFace/data/test_videos/...                 26.66
#
#   pct_of_frame
# 0       0.0708
# 1       0.0715
# 2       0.0695
# 3       0.0722
# 4       0.0698
#
# [5 rows x 23 columns]

# %%
row = df.iloc[3]
draw_to_center(row)
print(distance_from_center(row))
# Out:
# 11.05

# %%
x = int((row['x2'] - row['x1'])/2) + row['x1']
y = int((row['y2'] - row['y1'])/2) + row['y1']

xx = int(row['img_width']/2)
yy = int(row['img_height']/2)
a = abs(yy - y) 
b = abs(xx - x)
c = np.sqrt(a*a + b*b)

# %%
print(x,y)
print(xx,yy)
# Out:
# 623 253
# 640 360

# %%
print(a, b, c)
# Out:
# 107 17 108.34205093129813
