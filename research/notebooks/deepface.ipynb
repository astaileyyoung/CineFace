# %%
import cv2
from deepface import DeepFace

# %%
e = DeepFace.represent(img_path='../images/img_1.jpg', model_name='Facenet')
# Out:
# 2024-05-10 13:27:54.830936: W tensorflow/core/framework/op_kernel.cc:1827] UNKNOWN: JIT compilation failed.
# 2024-05-10 13:27:54.830962: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: UNKNOWN: JIT compilation failed.
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 e = DeepFace.represent(img_path='../images/img_1.jpg', model_name='Facenet')
#
# File ~/anaconda3/envs/deepface/lib/python3.11/site-packages/deepface/DeepFace.py:388, in represent(img_path, model_name, enforce_detection, detector_backend, align, expand_percentage, normalization)
#     335 def represent(
#     336     img_path: Union[str, np.ndarray],
#     337     model_name: str = "VGG-Face",
#    (...)
#     342     normalization: str = "base",
#     343 ) -> List[Dict[str, Any]]:
#     344     """
# ...

# %%
img = cv2.imread('../images/img_1.jpg')
img
# Out:
# array([[[  8,   8,   8],
#         [ 15,  15,  15],
#         [ 19,  19,  19],
#         ...,
#         [212, 212, 212],
#         [217, 217, 217],
#         [177, 177, 177]],
#
#        [[ 29,  29,  29],
#         [ 37,  37,  37],
#         [ 44,  44,  44],
#         ...,
#         [250, 250, 250],
#         [253, 253, 253],
#         [212, 212, 212]],
#
#        [[ 26,  26,  26],
#         [ 35,  35,  35],
#         [ 43,  43,  43],
#         ...,
#         [252, 252, 252],
#         [255, 255, 255],
#         [214, 214, 214]],
#
#        ...,
#
#        [[ 39,  39,  39],
#         [ 51,  51,  51],
#         [ 53,  53,  53],
#         ...,
#         [105, 105, 105],
#         [109, 109, 109],
#         [ 89,  89,  89]],
#
#        [[ 40,  40,  40],
#         [ 52,  52,  52],
#         [ 53,  53,  53],
#         ...,
#         [105, 105, 105],
#         [109, 109, 109],
#         [ 90,  90,  90]],
#
#        [[ 40,  40,  40],
#         [ 52,  52,  52],
#         [ 53,  53,  53],
# ...
