# %%
from imdb import Cinemagoer
from tmdbv3api import TMDb, TV, Find, Season, Episode, exceptions, Person

# %%
tmdb = TMDb()
tmdb.api_key = '64a6b6f9419ae4cba5b9a5f1c9e87401'

# %%
person = Person()

# %%
cast_id = 1206
p = Person(cast_id)

# %%
ids = person.external_ids(cast_id)
ids
# Out:
# {'id': 1206, 'freebase_mid': '/m/01w0yrc', 'freebase_id': None, 'imdb_id': 'nm0004517', 'tvrage_id': 22616, 'wikidata_id': 'Q311754', 'facebook_id': None, 'instagram_id': 'jalexander1959', 'tiktok_id': None, 'twitter_id': 'IJasonAlexander', 'youtube_id': None}

# %%
imdb_id = ids['imdb_id']
imdb_id
# Out:
# 'nm0004517'

# %%
from imdb.Person import Person

# %%
ia = Cinemagoer()

# %%
imdb_person = ia.get_person(imdb_id[2:])
imdb_person
# Out:
# <Person id:0004517[http] name:_Jason Alexander (I)_>

# %%
imdb_person['headshot']
# Out:
# 'https://m.media-amazon.com/images/M/MV5BMTYxNzMyMDY1OV5BMl5BanBnXkFtZTcwMDU3NjYyMw@@._V1_QL75_UY207_CR10,0,140,207_.jpg'

# %%
imdb_person.__dict__
# Out:
# {'data': {'headshot': 'https://m.media-amazon.com/images/M/MV5BMTYxMDkwMjM5NV5BMl5BanBnXkFtZTcwMzUxMTgxNw@@._V1_QL75_UX140_CR0,2,140,207_.jpg',
#   'imdbID': '0000632',
#   'name': 'Jerry Seinfeld'},
#  'myID': None,
#  'notes': '',
#  'titlesRefs': {'The Tonight Show Starring Johnny Carson (1962)': <Movie id:0055708[http] title:_The Tonight Show Starring Johnny Carson (1962)_>,
#   'The Merv Griffin Show (1962)': <Movie id:0055691[http] title:_The Merv Griffin Show (1962)_>,
#   'Benson (1979)': <Movie id:0078569[http] title:_Benson (1979)_>,
#   'Seinfeld (1989)': <Movie id:0098904[http] title:_Seinfeld (1989)_>,
#   'Seinfeld': <Movie id:0098904[http] title:_Seinfeld (None)_>,
#   'Bee Movie': <Movie id:0389790[http] title:_Bee Movie (None)_>,
#   'Unfrosted': <Movie id:14914430[http] title:_Unfrosted (None)_>,
#   'Comedians in Cars Getting Coffee': <Movie id:2314952[http] title:_Comedians in Cars Getting Coffee (None)_>},
#  'namesRefs': {'Biography': <Person id:0000632[http] name:_Biography_>,
#   'Awards': <Person id:0000632[http] name:_Awards_>,
#   'Trivia': <Person id:0000632[http] name:_Trivia_>,
#   'FAQ': <Person id:0000632[http] name:_FAQ_>,
#   'Rodney Dangerfield': <Person id:0001098[http] name:_Rodney Dangerfield_>,
#   'Larry David': <Person id:0202970[http] name:_Larry David_>,
#   'Won 1 Primetime Emmy': <Person id:0000632[http] name:_Won 1 Primetime Emmy_>,
#   'Official sites': <Person id:0000632[http] name:_Official sites_>,
#   'Jessica Seinfeld': <Person id:1367997[http] name:_Jessica Seinfeld_>,
#   'Carolyn Liebling': <Person id:2968871[http] name:_Carolyn Liebling_>,
#   'Other works': <Person id:0000632[http] name:_Other works_>,
#   'Publicity listings': <Person id:0000632[http] name:_Publicity listings_>,
#   '3 Print Biographies': <Person id:0000632[http] name:_3 Print Biographies_>,
#   '3 Portrayals': <Person id:0000632[http] name:_3 Portrayals_>,
#   '7 Interviews': <Person id:0000632[http] name:_7 Interviews_>,
#   '42 Articles': <Person id:0000632[http] name:_42 Articles_>,
#   '1 Pictorial': <Person id:0000632[http] name:_1 Pictorial_>,
#   '18 Magazine Cover Photos': <Person id:0000632[http] name:_18 Magazine Cover Photos_>,
#   'Quotes': <Person id:0000632[http] name:_Quotes_>,
#   'How old is Jerry Seinfeld?': <Person id:0000632[http] name:_How old is Jerry Seinfeld?_>,
#   'When was Jerry Seinfeld born?': <Person id:0000632[http] name:_When was Jerry Seinfeld born?_>,
#   'Where was Jerry Seinfeld born?': <Person id:0000632[http] name:_Where was Jerry Seinfeld born?_>,
#   'Back': <Person id:0000632[http] name:_Back_>,
#   'Billy Joel': <Person id:0005055[http] name:_Billy Joel_>},
#  'charactersRefs': {},
#  'modFunct': <function imdb.utils.modClearRefs(s, titlesRefs, namesRefs, charactersRefs)>,
#  'current_info': ['main', 'filmography', 'biography'],
#  'infoset2keys': {'main': ['headshot', 'imdbID', 'name'],
#   'filmography': [],
#   'biography': []},
#  'key2infoset': {'headshot': 'main', 'imdbID': 'main', 'name': 'main'},
#  '_Container__role': None,
#  'personID': '0000632',
#  'myName': '',
#  'billingPos': None,
#  'accessSystem': 'http',
#  'keys_tomodify': {'mini biography': None,
#   'spouse': None,
#   'quotes': None,
#   'other works': None,
#   'salary history': None,
#   'trivia': None,
#   'trade mark': None,
#   'news': None,
#   'books': None,
#   'biographical movies': None,
#   'portrayed in': None,
#   'where now': None,
#   'interviews': None,
#   'article': None,
#   "biography from leonard maltin's movie encyclopedia": None},
#  '_roleIsPerson': False,
#  '_roleClass': imdb.Character.Character}
