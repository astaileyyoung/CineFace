# %%
from imdb import Cinemagoer

# %%
ia = Cinemagoer()
imdb_id = 795129
r = ia.get_movie(imdb_id)

# %%
r.data.keys()
# Out:
# dict_keys(['localized title', 'cast', 'genres', 'runtimes', 'countries', 'country codes', 'language codes', 'color info', 'certificates', 'rating', 'votes', 'cover url', 'imdbID', 'videos', 'languages', 'title', 'year', 'kind', 'series years', 'original title', 'akas', 'writer', 'distributors', 'other companies', 'plot'])

# %%
r.data['genres']
# Out:
# ['Reality-TV']
