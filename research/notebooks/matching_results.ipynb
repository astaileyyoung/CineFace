# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/test_predicted.csv', index_col=0)
df.head()
# Out:
#       x1     y1     x2     y2  right_eye_x  right_eye_y  left_eye_x  \
# 0  0.216  0.234  0.361  0.599        0.295        0.396       0.337
# 1  0.001  0.186  0.078  0.392        0.037        0.272       0.068
# 2  0.404  0.205  0.537  0.562        0.475        0.355       0.506
# 3  0.188  0.165  0.275  0.377        0.235        0.249       0.265
# 4  0.042  0.121  0.108  0.288        0.075        0.187       0.099
#
#    left_eye_y  nose_x  nose_y  ...  face_num  frame_num  img_width  \
# 0       0.368   0.352   0.438  ...         0        192       1920
# 1       0.267   0.064   0.304  ...         1        192       1920
# 2       0.330   0.523   0.400  ...         0        216       1920
# 3       0.250   0.263   0.281  ...         1        216       1920
# 4       0.188   0.098   0.210  ...         2        216       1920
#
#    img_height                                           filepath  \
# 0        1080  /home/amos/media/tv/House.MD.2004.S01-08.1080p...
# ...

# %%
df[df['predicted_name'].notna()]
# Out:
#          x1     y1     x2     y2  right_eye_x  right_eye_y  left_eye_x  \
# 0     0.216  0.234  0.361  0.599        0.295        0.396       0.337
# 2     0.404  0.205  0.537  0.562        0.475        0.355       0.506
# 7     0.361  0.171  0.501  0.529        0.408        0.321       0.471
# 10    0.376  0.242  0.508  0.585        0.418        0.390       0.476
# 14    0.176  0.232  0.345  0.664        0.230        0.416       0.305
# ...     ...    ...    ...    ...          ...          ...         ...
# 3171  0.503  0.231  0.688  0.644        0.589        0.396       0.663
# 3172  0.215  0.000  0.577  0.791        0.273        0.345       0.417
# 3173  0.248  0.000  0.622  0.791        0.321        0.346       0.468
# 3174  0.250  0.000  0.611  0.776        0.322        0.313       0.468
# 3175  0.245  0.000  0.608  0.767        0.316        0.330       0.461
#
#       left_eye_y  nose_x  nose_y  ...  face_num  frame_num  img_width  \
# ...
