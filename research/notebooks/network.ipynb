# %%
import warnings
from functools import partial

import numpy as np
import pandas as pd
import networkx as nx
import plotly.graph_objs as go
from tqdm.auto import tqdm

# %% [markdown]
# # Create Network DataFrame

# %%
faces_df = pd.read_csv('./data/faces.csv', index_col=0)
character_df = faces_df[faces_df['character'].notna()]

# %%
def f(row,
      df):
    temp = df['frame_num'].map(lambda x: abs(frame_num - x))
    datum = {
         'min': temp.min(), 
         'max': temp.max(),
         'mean': int(round(temp.mean(), 0)),
         'median': int(temp.median())
        }
    return datum

# %%
def calc_frame_distance(a,
                        b,
                        df):
    a_df = character_df[character_df['character'] == a]
    b_df = character_df[character_df['character'] == b]
    func = partial(f, df=b_df)
    tqdm().pandas()
    temp = a_df.progress_apply(func, axis=1)
    data = []
    for x in temp:
        datum['character'] = a
        datum['target'] = b
        data.append(datum)
    return data

# %%
a = 'Carrie Mathison'
b = 'Peter Quinn'
df = pd.DataFrame(calc_frame_distance(a, b, character_df))
df.head()
# Out:
# 0it [00:00, ?it/s]
#   0%|          | 0/33897 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 3
#       1 a = 'Carrie Mathison'
#       2 b = 'Peter Quinn'
# ----> 3 df = pd.DataFrame(calc_frame_distance(a, b, character_df))
#       4 df.head()
#
# Cell In[33], line 8, in calc_frame_distance(a, b, df)
#       6 func = partial(f, df=b_df)
#       7 tqdm().pandas()
# ----> 8 temp = a_df.progress_apply(func, axis=1)
#       9 data = []
#      10 for x in temp:
#
# File ~/local/anaconda/envs/homeland/lib/python3.9/site-packages/tqdm/std.py:920, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     917 # Apply the provided function (in **kwargs)
#     918 # on the df using our wrapper (which provides bar updating)
#     919 try:
# --> 920     return getattr(df, df_function)(wrapper, **kwargs)
#     921 finally:
#     922     t.close()
#
# File ~/local/anaconda/envs/homeland/lib/python3.9/site-packages/pandas/core/frame.py:10037, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10025 from pandas.core.apply import frame_apply
#   10027 op = frame_apply(
#   10028     self,
#   10029     func=func,
#    (...)
#   10035     kwargs=kwargs,
#   10036 )
# > 10037 return op.apply().__finalize__(self, method="apply")
#
# File ~/local/anaconda/envs/homeland/lib/python3.9/site-packages/pandas/core/apply.py:831, in FrameApply.apply(self)
#     828 elif self.raw:
#     829     return self.apply_raw()
# --> 831 return self.apply_standard()
#
# File ~/local/anaconda/envs/homeland/lib/python3.9/site-packages/pandas/core/apply.py:957, in FrameApply.apply_standard(self)
#     956 def apply_standard(self):
# --> 957     results, res_index = self.apply_series_generator()
#     959     # wrap results
#     960     return self.wrap_results(results, res_index)
#
# File ~/local/anaconda/envs/homeland/lib/python3.9/site-packages/pandas/core/apply.py:973, in FrameApply.apply_series_generator(self)
#     970 with option_context("mode.chained_assignment", None):
#     971     for i, v in enumerate(series_gen):
#     972         # ignore SettingWithCopy here in case the user mutates
# --> 973         results[i] = self.func(v, *self.args, **self.kwargs)
#     974         if isinstance(results[i], ABCSeries):
#     975             # If we have a view on v, we need to make a copy because
#     976             #  series_generator will swap out the underlying data
#     977             results[i] = results[i].copy(deep=False)
#
# File ~/local/anaconda/envs/homeland/lib/python3.9/site-packages/tqdm/std.py:915, in tqdm.pandas.<locals>.inner_generator.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     909 def wrapper(*args, **kwargs):
#     910     # update tbar correctly
#     911     # it seems `pandas apply` calls `func` twice
#     912     # on the first column/row to decide whether it can
#     913     # take a fast or slow code path; so stop when t.total==t.n
#     914     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 915     return func(*args, **kwargs)
#
# Cell In[32], line 3, in f(row, df)
#       1 def f(row,
#       2       df):
# ----> 3     temp = df['frame_num'].map(lambda x: abs(frame_num - x))
#       4     datum = {
#       5          'min': temp.min(),
#       6          'max': temp.max(),
#       7          'mean': int(round(temp.mean(), 0)),
#       8          'median': int(temp.median())
#       9         }
#      10     return datum
#
# File ~/local/anaconda/envs/homeland/lib/python3.9/site-packages/pandas/core/series.py:4540, in Series.map(self, arg, na_action)
#    4460 def map(
#    4461     self,
#    4462     arg: Callable | Mapping | Series,
#    4463     na_action: Literal["ignore"] | None = None,
#    4464 ) -> Series:
#    4465     """
#    4466     Map values of Series according to an input mapping or function.
#    4467
#    (...)
#    4538     dtype: object
#    4539     """
# -> 4540     new_values = self._map_values(arg, na_action=na_action)
#    4541     return self._constructor(new_values, index=self.index, copy=False).__finalize__(
#    4542         self, method="map"
#    4543     )
#
# File ~/local/anaconda/envs/homeland/lib/python3.9/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/local/anaconda/envs/homeland/lib/python3.9/site-packages/pandas/core/algorithms.py:1812, in map_array(arr, mapper, na_action, convert)
#    1810 values = arr.astype(object, copy=False)
#    1811 if na_action is None:
# -> 1812     return lib.map_infer(values, mapper, convert=convert)
#    1813 else:
#    1814     return lib.map_infer_mask(
#    1815         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1816     )
#
# KeyboardInterrupt:

# %%
a = 'Carrie Mathison'
b = 'Saul Berenson'
episode_df = character_df[(character_df['season'] == 1) & (character_df['episode'])]
a_df = episode_df[episode_df['character'] == a]
b_df = episode_df[episode_df['character'] == b]
print(a_df.shape[0])
print(b_df.shape[0])
# Out:
# 2461
# 959

# %%
def func(a,
         b,
         season,
         episode,
         df):
    episode_df = character_df[(character_df['season'] == season) & (character_df['episode'] == episode)]
    a_df = episode_df[episode_df['character'] == a]
    b_df = episode_df[episode_df['character'] == b]

    a_df = a_df[['character', 'frame_num']].rename({'character': 'character_a', 
                                                'frame_num': 'frame_num_a'}, axis=1)
    b_df = b_df[['character', 'frame_num']].rename({'character': 'character_b', 
                                                    'frame_num': 'frame_num_b'}, axis=1)
    c_df = pd.concat([a_df, b_df], axis=1)
    c_df['character_a'] = c_df['character_a'].ffill()
    c_df['frame_num_a'] = c_df['frame_num_a'].ffill()
    c_df['character_b'] = c_df['character_b'].bfill()
    c_df['frame_num_b'] = c_df['frame_num_b'].bfill()

    c_df['distance'] = abs(c_df['frame_num_b'] - c_df['frame_num_a'])
    with warnings.catch_warnings():
        warnings.simplefilter("ignore", category=RuntimeWarning)
        datum = {
            'character': a,
            'target': b,
            'season': season,
            'episode': episode,
            'min': c_df['distance'].min() if c_df.shape[0] > 0 else np.nan,
            'max': c_df['distance'].max() if c_df.shape[0] > 0 else np.nan,
            'mean': c_df['distance'].mean() if c_df.shape[0] > 0 else np.nan,
            'median': c_df['distance'].median() if c_df.shape[0] > 0 else np.nan
            }
        return datum

# %%
characters = character_df['character'].unique()

data = []
pb = tqdm(total=8 * 12 * characters.shape[0] * characters.shape[0])
for a in list(characters):
    for b in characters:
        if a == b:
            continue
        for season in range(1, 9):
            for episode in range(1, 13):
                datum = func(a,
                             b,
                             season,
                             episode,
                             character_df)
                data.append(datum)
                pb.update()
# Out:
#   0%|          | 0/457056 [00:00<?, ?it/s]

# %%
network_df = pd.DataFrame(data)
network_df.head()
# Out:
#          character       target  season  episode    min      max  \
# 0  Carrie Mathison  David Estes       1        1   24.0  74664.0
# 1  Carrie Mathison  David Estes       1        2  504.0  45000.0
# 2  Carrie Mathison  David Estes       1        3  120.0  66312.0
# 3  Carrie Mathison  David Estes       1        4    NaN      NaN
# 4  Carrie Mathison  David Estes       1        5  192.0  76392.0
#
#            mean   median
# 0  42917.073930  48360.0
# 1  22087.709369  20928.0
# 2  35896.589641  32700.0
# 3           NaN      NaN
# 4  37476.438430  32760.0

# %%
network_df.to_csv('./data/network.csv')

# %% [markdown]
# # Create Network Map

# %% [markdown]
# ## Example Network Maps

# %% [markdown]
# ### Networkx

# %%
G = nx.random_geometric_graph(200, 0.125)

# %%
edge_x = []
edge_y = []
for edge in G.edges():
    x0, y0 = G.nodes[edge[0]]['pos']
    x1, y1 = G.nodes[edge[1]]['pos']
    edge_x.append(x0)
    edge_x.append(x1)
    edge_x.append(None)
    edge_y.append(y0)
    edge_y.append(y1)
    edge_y.append(None)

# %%
edge_trace = go.Scatter(
    x=edge_x, y=edge_y,
    line=dict(width=0.5, color='#888'),
    hoverinfo='none',
    mode='lines')

# %%
node_x = []
node_y = []
for node in G.nodes():
    x, y = G.nodes[node]['pos']
    node_x.append(x)
    node_y.append(y)

# %%
node_trace = go.Scatter(
    x=node_x, y=node_y,
    mode='markers',
    hoverinfo='text',
    marker=dict(
        showscale=True,
        # colorscale options
        #'Greys' | 'YlGnBu' | 'Greens' | 'YlOrRd' | 'Bluered' | 'RdBu' |
        #'Reds' | 'Blues' | 'Picnic' | 'Rainbow' | 'Portland' | 'Jet' |
        #'Hot' | 'Blackbody' | 'Earth' | 'Electric' | 'Viridis' |
        colorscale='YlGnBu',
        reversescale=True,
        color=[],
        size=10,
        colorbar=dict(
            thickness=15,
            title='Node Connections',
            xanchor='left',
            titleside='right'
        ),
        line_width=2))

# %%
node_adjacencies = []
node_text = []
for node, adjacencies in enumerate(G.adjacency()):
    node_adjacencies.append(len(adjacencies[1]))
    node_text.append('# of connections: '+str(len(adjacencies[1])))

node_trace.marker.color = node_adjacencies
node_trace.text = node_text

# %%
fig = go.Figure(data=[edge_trace, node_trace],
             layout=go.Layout(
                title='<br>Network graph made with Python',
                titlefont_size=16,
                showlegend=False,
                hovermode='closest',
                margin=dict(b=20,l=5,r=5,t=40),
                annotations=[ dict(
                    text="Python code: <a href='https://plotly.com/ipython-notebooks/network-graphs/'> https://plotly.com/ipython-notebooks/network-graphs/</a>",
                    showarrow=False,
                    xref="paper", yref="paper",
                    x=0.005, y=-0.002 ) ],
                xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                yaxis=dict(showgrid=False, zeroline=False, showticklabels=False))
                )
fig.show()

# %% [markdown]
# ### Tutorial

# %%
network_counts = network_df[network_df.notna()]
counts = faces_df['character'].value_counts().sort_values(ascending=False).iloc[:10]
network_counts = network_counts[(network_counts['character'].isin(counts.index)) &
                                (network_counts['target'].isin(counts.index))]
# network_counts = network_counts.merge(counts,
#                                   how='inner',
#                                   right_index=True,
#                                   left_on='character')
# network_counts = network_counts.merge(counts,
#                                   how='inner',
#                                   right_index=True,
#                                   left_on='target')

network_counts.head()
# Out:
#            character         target  season  episode   min      max  \
# 96   Carrie Mathison  Saul Berenson       1        1  72.0  65592.0
# 97   Carrie Mathison  Saul Berenson       1        2  24.0  69672.0
# 98   Carrie Mathison  Saul Berenson       1        3  48.0  66624.0
# 99   Carrie Mathison  Saul Berenson       1        4   NaN      NaN
# 100  Carrie Mathison  Saul Berenson       1        5  96.0  76128.0
#
#              mean   median
# 96   34107.871921  38136.0
# 97   40146.259965  42024.0
# 98   36963.890710  41256.0
# 99            NaN      NaN
# 100  37502.217090  39408.0

# %%
to_list = network_counts['character'].tolist()
from_list = network_counts['target'].tolist()

# %%
G = nx.Graph()
node_list = network_counts['character'].tolist()
for i in range(network_counts.shape[0]):
    G.add_node(node_list[i])
    G.add_edges_from([(from_list[i], to_list[i])])

# %%
pos = nx.spring_layout(G, k=0.5, iterations=100)
for n, p in pos.items():
    G.nodes[n]['pos'] = p

# %%
edge_trace = go.Scatter(
    x=[],
    y=[],
    line=dict(width=0.5, color='#888'),
    hoverinfo='none',
    mode='lines')
for edge in G.edges():
    x0, y0 = G.nodes[edge[0]]['pos']
    x1, y1 = G.nodes[edge[1]]['pos']
    edge_trace['x'] += tuple([x0, x1, None])
    edge_trace['y'] += tuple([y0, y1, None])

# %%
node_trace = go.Scatter(
    x=[],
    y=[],
    text=[],
    mode='markers+text',
    hoverinfo='text',
    marker=dict(
        showscale=True,
        colorscale='pinkyl',
        reversescale=True,
        color=[],
        size=37,
        colorbar=dict(
            thickness=1,
            title='Node Connections',
            xanchor='left',
            titleside='right'
        ),
        line=dict(width=0)))
for node in G.nodes():
    x, y = G.nodes[node]['pos']
    node_trace['x'] += tuple([x])
    node_trace['y'] += tuple([y])
for node, adjacencies in enumerate(G.adjacency()):
    node_trace['marker']['color'] += tuple([len(adjacencies[1])])
    node_info = adjacencies[0]
    node_trace['text'] += tuple([node_info])

# %%
title = "Network Graph Demonstration"
fig = go.Figure(data=[edge_trace, node_trace],
                layout=go.Layout(
                title=title,
                titlefont=dict(size=16),
                showlegend=False,
                hovermode='closest',
                margin=dict(b=21, l=5, r=5, t=40),
                annotations=[dict(
                    text="Text Here",
                    showarrow=False,
                    xref="paper", yref="paper")],
                xaxis=dict(showgrid=False, zeroline=False,
                           showticklabels=False, mirror=True),
                yaxis=dict(showgrid=False, zeroline=False, showticklabels=False, mirror=True)))
fig.show()

# %%
network_df[(network_df['character'] == 'David Wellington') &
           (network_df['target'] == 'Nicholas Brody')]
# Out:
#                character          target  season  episode     min      max  \
# 320160  David Wellington  Nicholas Brody       1        1     NaN      NaN
# 320161  David Wellington  Nicholas Brody       1        2     NaN      NaN
# 320162  David Wellington  Nicholas Brody       1        3     NaN      NaN
# 320163  David Wellington  Nicholas Brody       1        4     NaN      NaN
# 320164  David Wellington  Nicholas Brody       1        5     NaN      NaN
# ...                  ...             ...     ...      ...     ...      ...
# 320251  David Wellington  Nicholas Brody       8        8     NaN      NaN
# 320252  David Wellington  Nicholas Brody       8        9     NaN      NaN
# 320253  David Wellington  Nicholas Brody       8       10     NaN      NaN
# 320254  David Wellington  Nicholas Brody       8       11     NaN      NaN
# 320255  David Wellington  Nicholas Brody       8       12  2088.0  70056.0
#
#                 mean   median
# 320160           NaN      NaN
# 320161           NaN      NaN
# 320162           NaN      NaN
# 320163           NaN      NaN
# 320164           NaN      NaN
# ...              ...      ...
# 320251           NaN      NaN
# 320252           NaN      NaN
# 320253           NaN      NaN
# 320254           NaN      NaN
# 320255  37602.446281  47760.0
#
# [96 rows x 8 columns]
