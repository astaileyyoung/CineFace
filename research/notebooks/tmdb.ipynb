# %%
from tmdbv3api import TMDb, TV, Find, Season, Episode, exceptions, Person

# %%
tmdb = TMDb()
tmdb.api_key = '64a6b6f9419ae4cba5b9a5f1c9e87401'

# %%
p = Person()
d = p.details(8263)
d
# Out:
# {'adult': False, 'also_known_as': ['Andrea Louise Martin', 'آندریا مارتین'], 'biography': 'Andrea Martin is an American-Canadian stage and screen actress, writer and comedian.', 'birthday': '1947-01-15', 'deathday': None, 'gender': 1, 'homepage': None, 'id': 8263, 'imdb_id': 'nm0551908', 'known_for_department': 'Acting', 'name': 'Andrea Martin', 'place_of_birth': 'Portland, Maine, USA', 'popularity': 9.388, 'profile_path': '/lOP6nvTOvqpdHtEMfLCvNqUaRnp.jpg', 'images': {'profiles': [{'aspect_ratio': 0.667, 'height': 1024, 'iso_639_1': None, 'file_path': '/lOP6nvTOvqpdHtEMfLCvNqUaRnp.jpg', 'vote_average': 3.334, 'vote_count': 2, 'width': 683}, {'aspect_ratio': 0.666, 'height': 1118, 'iso_639_1': None, 'file_path': '/viSxKSIT09XJfSMO8jNn1AzNH0W.jpg', 'vote_average': 2.278, 'vote_count': 3, 'width': 745}, {'aspect_ratio': 0.667, 'height': 1230, 'iso_639_1': None, 'file_path': '/syS5bfwIeFAFzAWtn0dqPbfPadM.jpg', 'vote_average': 1.75, 'vote_count': 2, 'width': 820}, {'aspect_ratio': 0.667, 'height': 3000, 'iso_639_1': None, 'file_path': '/ePp9bGdNEUsr3CjZRuLq1iVFcC2.jpg', 'vote_average': 1.75, 'vote_count': 2, 'width': 2000}, {'aspect_ratio': 0.667, 'height': 1500, 'iso_639_1': None, 'file_path': '/vHCcXFU85VVXiaw46qg33u54nsq.jpg', 'vote_average': 0.0, 'vote_count': 0, 'width': 1000}]}}

# %%
type(d['id'])
# Out:
# int
