# %%
import os
import sys

import numpy as np
import pandas as pd
import plotly.express as px
import dataframe_image as dfi
import plotly.graph_objects as go
from scipy import stats 
import sqlalchemy as db

sys.path.append(os.path.abspath(os.path.join('../..')))

from utils import *

# %%
username = "amos"
password = "M0$hicat"
host = "192.168.0.131"
port = "3306"
database = "CineFaceDW"
connection_string = f'mysql+pymysql://{username}:{password}@{host}:{port}/{database}'
engine = db.create_engine(connection_string)

# %%
name = "Wong Kar-Wai"

# %%
df = pd.read_sql(f"SELECT * FROM vwWorksByDirector WHERE kind = 'movie'", engine)
df
# Out:
#       person_id        person_name  \
# 0        100036      D.W. Griffith
# 1         41611  Giovanni Pastrone
# 2       1037794         Lois Weber
# 3        100036      D.W. Griffith
# 4       1307858     Colin Campbell
# ...         ...                ...
# 7642        309    Pedro Almodóvar
# 7643      67367       Rian Johnson
# 7644      67367       Rian Johnson
# 7645      67367       Rian Johnson
# 7646      14392    Kathryn Bigelow
#
#                                                   title  year   kind  runtime  \
# 0     The Avenging Conscience: or 'Thou Shalt Not Kill'  1914  movie     78.0
# 1                                               Cabiria  1914  movie    148.0
# 2                                            Hypocrites  1915  movie     54.0
# 3                                    Judith of Bethulia  1914  movie     61.0
# 4                                          The Spoilers  1914  movie    110.0
# ...                                                 ...   ...    ...      ...
# 7642                                     Dolor y gloria  2019  movie    113.0
# 7643                                         Knives Out  2019  movie    130.0
# 7644                                        Glass Onion  2022  movie    139.0
# 7645                                   Wake Up Dead Man  2025  movie    144.0
# 7646                                A House of Dynamite  2025  movie    112.0
#
#       fact_id   imdb_id  work_id  avg_size  ...  z_v_density_tv  \
# 0         251      3643    32807    0.0176  ...            None
# 1         256      3740    32809    0.0056  ...            None
# 2         270      4134    32812    0.0089  ...            None
# 3         272      4181    32813    0.0087  ...            None
# 4         289      4630    32816    0.0101  ...            None
# ...       ...       ...      ...       ...  ...             ...
# 7642     9772   8291806    56846    0.0374  ...            None
# 7643     9778   8946378    56847    0.0529  ...            None
# 7644     9447  11564570    56848    0.0332  ...            None
# 7645     9464  14364480    56849    0.0515  ...            None
# 7646     9495  32376165    56850    0.0430  ...            None
#
#       z_v_density_tv_g  z_pct_face_tv  z_pct_face_tv_g  z_v_pct_face_tv  \
# 0                 None           None             None             None
# 1                 None           None             None             None
# 2                 None           None             None             None
# 3                 None           None             None             None
# 4                 None           None             None             None
# ...                ...            ...              ...              ...
# 7642              None           None             None             None
# 7643              None           None             None             None
# 7644              None           None             None             None
# 7645              None           None             None             None
# 7646              None           None             None             None
#
#       z_v_pct_face_tv_g  z_pct_top1_tv  z_pct_top1_tv_g  z_v_pct_top1_tv  \
# 0                  None           None             None             None
# 1                  None           None             None             None
# 2                  None           None             None             None
# 3                  None           None             None             None
# 4                  None           None             None             None
# ...                 ...            ...              ...              ...
# 7642               None           None             None             None
# 7643               None           None             None             None
# 7644               None           None             None             None
# 7645               None           None             None             None
# 7646               None           None             None             None
#
#       z_v_pct_top1_tv_g
# 0                  None
# 1                  None
# 2                  None
# 3                  None
# 4                  None
# ...                 ...
# 7642               None
# 7643               None
# 7644               None
# 7645               None
# 7646               None
#
# [7647 rows x 126 columns]

# %%
g = pd.read_sql("SELECT * FROM vwDirectorStats WHERE cnt > 5", engine)
g
# Out:
#      person_id                 name  cnt  avg_f_per_fr  z_size_mv_mean  \
# 0            1         George Lucas    6      1.597648       -0.053352
# 1           40         Orson Welles    9      1.770517        0.697528
# 2           68           Fritz Lang   33      1.873031       -0.432220
# 3          138    Quentin Tarantino    7      1.581424       -0.217380
# 4          190       Clint Eastwood   32      2.017244       -0.416212
# ..         ...                  ...  ...           ...             ...
# 328     940663  Chester M. Franklin    8      1.618405        0.397221
# 329    1021685      E. Mason Hopper    6      1.722700       -0.272303
# 330    1036754      Reginald Barker    7      1.812715        0.462617
# 331    1065336    Melville W. Brown    6      1.830765       -0.722426
# 332    1225777          Leigh Jason    7      2.091450        0.035561
#
#      z_size_mv_g_mean  z_size_mv_std  z_size_mv_g_std  z_top1_mv_mean  \
# 0            0.814914       0.783111         0.766601       -0.190065
# 1            0.110828       0.808529         0.445027        0.889053
# 2           -0.640721       0.738070         0.369027       -0.447708
# 3            0.863364       0.969357         1.334367       -0.287119
# 4            0.314150       0.702603         0.667530       -0.269060
# ..                ...            ...              ...             ...
# 328         -0.568999       0.979921         0.185540        0.344414
# 329         -0.544496       0.875573         0.382297       -0.368806
# 330         -0.635704       0.387553         0.375400        0.511501
# 331         -0.799145       0.455469         0.263664       -0.791800
# 332         -0.406215       0.444228         0.174203        0.024545
#
#      z_top1_mv_g_mean  ...  z_v_density_mv_mean  z_v_density_mv_g_mean  \
# 0            0.802465  ...             0.000000               0.000000
# 1            0.204514  ...             0.745900               0.449870
# 2           -0.691414  ...             0.064489              -0.170618
# 3            0.842447  ...            -0.286160               0.325392
# 4            0.586161  ...             0.029670               0.063425
# ..                ...  ...                  ...                    ...
# 328         -0.740273  ...            -0.017444               0.621329
# 329         -0.691033  ...            -0.234674              -0.300615
# 330         -0.746425  ...             0.359743               0.539909
# 331         -0.919072  ...            -0.030822              -0.239791
# 332         -0.447347  ...             0.075440              -0.314887
#
#      z_pct_top1_mv_mean  z_pct_top1_mv_g_mean  z_v_pct_top1_mv_mean  \
# 0              0.277344              0.991328             -0.111087
# 1              0.888112              0.327788              0.070874
# 2              0.384600             -0.147534              0.320935
# 3              0.116981              1.032773             -0.151320
# 4             -0.578839              0.328151              0.495116
# ..                  ...                   ...                   ...
# 328           -0.074203              0.162069              0.396381
# 329           -0.142999             -0.409118              0.188546
# 330           -0.135964             -0.138941              0.476722
# 331           -0.170180             -0.596750              0.235600
# 332           -0.587623             -0.964119             -0.176007
#
#      z_v_pct_top1_mv_g_mean  z_pct_face_mv_mean  z_pct_face_mv_g_mean  \
# 0                 -0.397079           -0.226912              0.660440
# 1                  0.214835            0.630211              0.140793
# 2                  0.367024           -0.660249             -0.775029
# 3                 -0.850129           -0.378893              0.631704
# 4                  0.198262           -0.136572              0.651149
# ..                      ...                 ...                   ...
# 328                0.419476            0.359364             -0.866964
# 329                0.391993           -0.542793             -0.771631
# 330                0.568228            0.635482             -0.770480
# 331                0.280355           -0.923024             -0.982991
# 332                0.104267            0.400758             -0.178973
#
#      z_v_pct_face_mv_mean  z_v_pct_face_mv_g_mean
# 0               -0.229422                0.845807
# 1                1.023617                0.451762
# 2               -0.107610               -0.558840
# 3                0.342752                1.289849
# 4               -0.389156                0.490620
# ..                    ...                     ...
# 328             -0.004262               -0.903669
# 329             -0.404528               -0.799606
# 330              0.400587               -0.831591
# 331             -0.877001               -1.104247
# 332              0.090061               -0.432101
#
# [333 rows x 66 columns]

# %%
x = "z_size_mv_g_mean"
y = "z_v_size_mv_g_mean"
plot_directors_against_sample(g, 
                              x, 
                              y, 
                              [name], 
                              x_title="Avg. Size (Z Score)", 
                              y_title="Size Variance (Z Score)", 
                              title="Wong Kar-Wai: Avg. Face Size vs. Std. Face Size", 
                              width=1200,
                              height=600,
                              dst="./plots/wong_kar_wai/wong_kar_wai_size_v_variance.png")

# %%
x = "z_f_per_fr_mv_g_mean"
y = "z_size_mv_g_mean"
plot_directors_against_sample(g, 
                              x, 
                              y, 
                              [name],
                              title=f"{name}: Avg. Faces per Frame vs. Avg. Face Size",
                              x_title="Avg. Faces per Frame (Z Score)",
                              y_title="Avg. Face Size (Z Score)",
                              dst="./plots/wong_kar_wai/wong_kar_wai_faces_per_fr_vs_avg_size.png",
                              width=1200,
                              height=600)

# %%
x = "z_f_per_fr_mv_g_mean"
y = "z_pct_top1_mv_g_mean"
plot_directors_against_sample(g, 
                              x, 
                              y, 
                              [name],
                              title=f"{name}: Avg. Faces per Frame vs. Pct. Singles",
                              x_title="Avg. Faces per Frame (Z Score)",
                              y_title="% Singles (Z Score)",
                              dst="./plots/wong_kar_wai/wong_kar_wai_faces_per_fr_vs_singles.png",
                              width=1200,
                              height=600)

# %%
x = "z_f_per_fr_mv_g_mean"
y = "z_disp_mv_g_mean"
plot_directors_against_sample(g, 
                              x, 
                              y, 
                              [name],
                              title=f"{name}: Faces per Frame vs. Dispersion",
                              width=1200,
                              height=600,
                              x_title="Faces per Frame (Z Score)",
                              y_title="Dispersion (Z Score)",
                              dst="./plots/wong_kar_wai/wong_kar_wai_f_per_fr_vs_disp.png"
                              )

# %%
x = "z_dist_mv_g_mean"
y = "z_v_dist_mv_g_mean"
plot_directors_against_sample(g, 
                              x, 
                              y, 
                              [name],
                              title=f"{name}: Avg. Distance from Center vs. Std. Distance from Center",
                              x_title="Avg. Distance from Center (Z Score)",
                              y_title="Std. Distance from Center (Z Score)",
                              dst="./plots/wong_kar_wai/wong_kar_wai_avg_dist_vs_std_dist.png",
                              width=1200,
                              height=600)

# %%
x = "z_disp_mv_g_mean"
y = "z_gini_mv_g_mean"
plot_directors_against_sample(g, 
                              x, 
                              y, 
                              [name],
                              title=f"{name}: Dispersion vs. Gini",
                              x_title="Dispersion (Z Score)",
                              y_title="Gini (Z Score)",
                              dst="./plots/wong_kar_wai/wong_kar_wai_disp_vs_gini.png",
                              width=1200,
                              height=600)
